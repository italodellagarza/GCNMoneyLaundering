# %% [markdown]
# # Teste Simples

# %%
import torch

# %% [markdown]
# ## Importando dados

# %%
data = []

for timestamp in range(200):
    data.append(torch.load(f'./1Kvertices-100Kedges_pt/{timestamp}.pt'))

# %%
data
# Out:
# [Data(x=[2, 338], edge_index=[2, 306], edge_attr=[3, 306], y=[306], node_to_node_adj_matr=[338, 338], node_to_edge_adj_matr=[338, 306], edge_to_node_adj_matr=[306, 338], edge_to_edge_adj_matr=[306, 306]),
#  Data(x=[2, 450], edge_index=[2, 451], edge_attr=[3, 451], y=[451], node_to_node_adj_matr=[450, 450], node_to_edge_adj_matr=[450, 451], edge_to_node_adj_matr=[451, 450], edge_to_edge_adj_matr=[451, 451]),
#  Data(x=[2, 420], edge_index=[2, 398], edge_attr=[3, 398], y=[398], node_to_node_adj_matr=[420, 420], node_to_edge_adj_matr=[420, 398], edge_to_node_adj_matr=[398, 420], edge_to_edge_adj_matr=[398, 398]),
#  Data(x=[2, 539], edge_index=[2, 587], edge_attr=[3, 587], y=[587], node_to_node_adj_matr=[539, 539], node_to_edge_adj_matr=[539, 587], edge_to_node_adj_matr=[587, 539], edge_to_edge_adj_matr=[587, 587]),
# ...

# %% [markdown]
# ## Estruturando Modelo
