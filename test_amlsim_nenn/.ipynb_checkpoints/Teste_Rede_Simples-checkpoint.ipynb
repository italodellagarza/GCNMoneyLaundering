# %% [markdown]
# # Teste Simples

# %%
import torch

# %% [markdown]
# ## Importando dados

# %%
data = []

for timestamp in range(200):
    data.append(torch.load(f'./1Kvertices-100Kedges_pt/{timestamp}.pt'))

# %%
data
# Out:
# [Data(x=[2, 338], edge_index=[2, 306], edge_attr=[3, 306], y=[306]),
#  Data(x=[2, 450], edge_index=[2, 451], edge_attr=[3, 451], y=[451]),
#  Data(x=[2, 420], edge_index=[2, 398], edge_attr=[3, 398], y=[398]),
#  Data(x=[2, 539], edge_index=[2, 587], edge_attr=[3, 587], y=[587]),
#  Data(x=[2, 609], edge_index=[2, 711], edge_attr=[3, 711], y=[711]),
#  Data(x=[2, 547], edge_index=[2, 595], edge_attr=[3, 595], y=[595]),
#  Data(x=[2, 579], edge_index=[2, 622], edge_attr=[3, 622], y=[622]),
#  Data(x=[2, 585], edge_index=[2, 650], edge_attr=[3, 650], y=[650]),
#  Data(x=[2, 514], edge_index=[2, 495], edge_attr=[3, 495], y=[495]),
#  Data(x=[2, 558], edge_index=[2, 556], edge_attr=[3, 556], y=[556]),
#  Data(x=[2, 467], edge_index=[2, 415], edge_attr=[3, 415], y=[415]),
#  Data(x=[2, 537], edge_index=[2, 587], edge_attr=[3, 587], y=[587]),
#  Data(x=[2, 522], edge_index=[2, 508], edge_attr=[3, 508], y=[508]),
#  Data(x=[2, 591], edge_index=[2, 691], edge_attr=[3, 691], y=[691]),
# ...
