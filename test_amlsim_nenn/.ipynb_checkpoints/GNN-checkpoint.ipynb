# %%
import os
from torch_geometric.data import Data
import torch

# %%
dataset = []
pt_files = []

for ptfile in sorted(os.listdir('concept_drift_31')):
    pt_files.append(f'concept_drift_31/{ptfile}')
    dataset.append(torch.load(f'concept_drift_31/{ptfile}'))

# %%
dataset
# Out:
# [Data(x=[6, 37], edge_index=[2, 19], edge_attr=[8, 19], y=[19], node_to_node_adj_matr=[37, 37], node_to_edge_adj_matr=[37, 19], edge_to_node_adj_matr=[19, 37], edge_to_edge_adj_matr=[19, 19]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 37], edge_index=[2, 19], edge_attr=[8, 19], y=[19], node_to_node_adj_matr=[37, 37], node_to_edge_adj_matr=[37, 19], edge_to_node_adj_matr=[19, 37], edge_to_edge_adj_matr=[19, 19]),
#  Data(x=[6, 15], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[15, 15], node_to_edge_adj_matr=[15, 8], edge_to_node_adj_matr=[8, 15], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 11], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[11, 11], node_to_edge_adj_matr=[11, 6], edge_to_node_adj_matr=[6, 11], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 31], edge_index=[2, 16], edge_attr=[8, 16], y=[16], node_to_node_adj_matr=[31, 31], node_to_edge_adj_matr=[31, 16], edge_to_node_adj_matr=[16, 31], edge_to_edge_adj_matr=[16, 16]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 24], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 13], edge_to_node_adj_matr=[13, 24], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 23], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[23, 23], node_to_edge_adj_matr=[23, 12], edge_to_node_adj_matr=[12, 23], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 4], edge_index=[2, 2], edge_attr=[8, 2], y=[2], node_to_node_adj_matr=[4, 4], node_to_edge_adj_matr=[4, 2], edge_to_node_adj_matr=[2, 4], edge_to_edge_adj_matr=[2, 2]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 22], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 12], edge_to_node_adj_matr=[12, 22], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 14], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 8], edge_to_node_adj_matr=[8, 14], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 31], edge_index=[2, 16], edge_attr=[8, 16], y=[16], node_to_node_adj_matr=[31, 31], node_to_edge_adj_matr=[31, 16], edge_to_node_adj_matr=[16, 31], edge_to_edge_adj_matr=[16, 16]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 19], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[19, 19], node_to_edge_adj_matr=[19, 10], edge_to_node_adj_matr=[10, 19], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 34], edge_index=[2, 17], edge_attr=[8, 17], y=[17], node_to_node_adj_matr=[34, 34], node_to_edge_adj_matr=[34, 17], edge_to_node_adj_matr=[17, 34], edge_to_edge_adj_matr=[17, 17]),
#  Data(x=[6, 28], edge_index=[2, 14], edge_attr=[8, 14], y=[14], node_to_node_adj_matr=[28, 28], node_to_edge_adj_matr=[28, 14], edge_to_node_adj_matr=[14, 28], edge_to_edge_adj_matr=[14, 14]),
#  Data(x=[6, 29], edge_index=[2, 15], edge_attr=[8, 15], y=[15], node_to_node_adj_matr=[29, 29], node_to_edge_adj_matr=[29, 15], edge_to_node_adj_matr=[15, 29], edge_to_edge_adj_matr=[15, 15]),
#  Data(x=[6, 17], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[17, 17], node_to_edge_adj_matr=[17, 9], edge_to_node_adj_matr=[9, 17], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 18], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 10], edge_to_node_adj_matr=[10, 18], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 19], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[19, 19], node_to_edge_adj_matr=[19, 10], edge_to_node_adj_matr=[10, 19], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 23], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[23, 23], node_to_edge_adj_matr=[23, 12], edge_to_node_adj_matr=[12, 23], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 25], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[25, 25], node_to_edge_adj_matr=[25, 13], edge_to_node_adj_matr=[13, 25], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 19], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[19, 19], node_to_edge_adj_matr=[19, 10], edge_to_node_adj_matr=[10, 19], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 15], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[15, 15], node_to_edge_adj_matr=[15, 8], edge_to_node_adj_matr=[8, 15], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 34], edge_index=[2, 18], edge_attr=[8, 18], y=[18], node_to_node_adj_matr=[34, 34], node_to_edge_adj_matr=[34, 18], edge_to_node_adj_matr=[18, 34], edge_to_edge_adj_matr=[18, 18]),
#  Data(x=[6, 37], edge_index=[2, 19], edge_attr=[8, 19], y=[19], node_to_node_adj_matr=[37, 37], node_to_edge_adj_matr=[37, 19], edge_to_node_adj_matr=[19, 37], edge_to_edge_adj_matr=[19, 19]),
#  Data(x=[6, 25], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[25, 25], node_to_edge_adj_matr=[25, 13], edge_to_node_adj_matr=[13, 25], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 30], edge_index=[2, 16], edge_attr=[8, 16], y=[16], node_to_node_adj_matr=[30, 30], node_to_edge_adj_matr=[30, 16], edge_to_node_adj_matr=[16, 30], edge_to_edge_adj_matr=[16, 16]),
#  Data(x=[6, 28], edge_index=[2, 14], edge_attr=[8, 14], y=[14], node_to_node_adj_matr=[28, 28], node_to_edge_adj_matr=[28, 14], edge_to_node_adj_matr=[14, 28], edge_to_edge_adj_matr=[14, 14]),
#  Data(x=[6, 30], edge_index=[2, 15], edge_attr=[8, 15], y=[15], node_to_node_adj_matr=[30, 30], node_to_edge_adj_matr=[30, 15], edge_to_node_adj_matr=[15, 30], edge_to_edge_adj_matr=[15, 15]),
#  Data(x=[6, 37], edge_index=[2, 19], edge_attr=[8, 19], y=[19], node_to_node_adj_matr=[37, 37], node_to_edge_adj_matr=[37, 19], edge_to_node_adj_matr=[19, 37], edge_to_edge_adj_matr=[19, 19]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 25], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[25, 25], node_to_edge_adj_matr=[25, 13], edge_to_node_adj_matr=[13, 25], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 28], edge_index=[2, 14], edge_attr=[8, 14], y=[14], node_to_node_adj_matr=[28, 28], node_to_edge_adj_matr=[28, 14], edge_to_node_adj_matr=[14, 28], edge_to_edge_adj_matr=[14, 14]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 29], edge_index=[2, 15], edge_attr=[8, 15], y=[15], node_to_node_adj_matr=[29, 29], node_to_edge_adj_matr=[29, 15], edge_to_node_adj_matr=[15, 29], edge_to_edge_adj_matr=[15, 15]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 6], edge_index=[2, 3], edge_attr=[8, 3], y=[3], node_to_node_adj_matr=[6, 6], node_to_edge_adj_matr=[6, 3], edge_to_node_adj_matr=[3, 6], edge_to_edge_adj_matr=[3, 3]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 4], edge_index=[2, 2], edge_attr=[8, 2], y=[2], node_to_node_adj_matr=[4, 4], node_to_edge_adj_matr=[4, 2], edge_to_node_adj_matr=[2, 4], edge_to_edge_adj_matr=[2, 2]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 6], edge_index=[2, 3], edge_attr=[8, 3], y=[3], node_to_node_adj_matr=[6, 6], node_to_edge_adj_matr=[6, 3], edge_to_node_adj_matr=[3, 6], edge_to_edge_adj_matr=[3, 3]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 23], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[23, 23], node_to_edge_adj_matr=[23, 12], edge_to_node_adj_matr=[12, 23], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 6], edge_index=[2, 3], edge_attr=[8, 3], y=[3], node_to_node_adj_matr=[6, 6], node_to_edge_adj_matr=[6, 3], edge_to_node_adj_matr=[3, 6], edge_to_edge_adj_matr=[3, 3]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 32], edge_index=[2, 17], edge_attr=[8, 17], y=[17], node_to_node_adj_matr=[32, 32], node_to_edge_adj_matr=[32, 17], edge_to_node_adj_matr=[17, 32], edge_to_edge_adj_matr=[17, 17]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 17], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[17, 17], node_to_edge_adj_matr=[17, 9], edge_to_node_adj_matr=[9, 17], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 30], edge_index=[2, 15], edge_attr=[8, 15], y=[15], node_to_node_adj_matr=[30, 30], node_to_edge_adj_matr=[30, 15], edge_to_node_adj_matr=[15, 30], edge_to_edge_adj_matr=[15, 15]),
#  Data(x=[6, 28], edge_index=[2, 14], edge_attr=[8, 14], y=[14], node_to_node_adj_matr=[28, 28], node_to_edge_adj_matr=[28, 14], edge_to_node_adj_matr=[14, 28], edge_to_edge_adj_matr=[14, 14]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 4], edge_index=[2, 2], edge_attr=[8, 2], y=[2], node_to_node_adj_matr=[4, 4], node_to_edge_adj_matr=[4, 2], edge_to_node_adj_matr=[2, 4], edge_to_edge_adj_matr=[2, 2]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 26], edge_index=[2, 14], edge_attr=[8, 14], y=[14], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 14], edge_to_node_adj_matr=[14, 26], edge_to_edge_adj_matr=[14, 14]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 21], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[21, 21], node_to_edge_adj_matr=[21, 11], edge_to_node_adj_matr=[11, 21], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 29], edge_index=[2, 15], edge_attr=[8, 15], y=[15], node_to_node_adj_matr=[29, 29], node_to_edge_adj_matr=[29, 15], edge_to_node_adj_matr=[15, 29], edge_to_edge_adj_matr=[15, 15]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 15], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[15, 15], node_to_edge_adj_matr=[15, 8], edge_to_node_adj_matr=[8, 15], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 17], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[17, 17], node_to_edge_adj_matr=[17, 9], edge_to_node_adj_matr=[9, 17], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 30], edge_index=[2, 16], edge_attr=[8, 16], y=[16], node_to_node_adj_matr=[30, 30], node_to_edge_adj_matr=[30, 16], edge_to_node_adj_matr=[16, 30], edge_to_edge_adj_matr=[16, 16]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 19], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[19, 19], node_to_edge_adj_matr=[19, 10], edge_to_node_adj_matr=[10, 19], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 16], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 10], edge_to_node_adj_matr=[10, 16], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 18], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 10], edge_to_node_adj_matr=[10, 18], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 13], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[13, 13], node_to_edge_adj_matr=[13, 7], edge_to_node_adj_matr=[7, 13], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 51], edge_index=[2, 26], edge_attr=[8, 26], y=[26], node_to_node_adj_matr=[51, 51], node_to_edge_adj_matr=[51, 26], edge_to_node_adj_matr=[26, 51], edge_to_edge_adj_matr=[26, 26]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 28], edge_index=[2, 14], edge_attr=[8, 14], y=[14], node_to_node_adj_matr=[28, 28], node_to_edge_adj_matr=[28, 14], edge_to_node_adj_matr=[14, 28], edge_to_edge_adj_matr=[14, 14]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 37], edge_index=[2, 19], edge_attr=[8, 19], y=[19], node_to_node_adj_matr=[37, 37], node_to_edge_adj_matr=[37, 19], edge_to_node_adj_matr=[19, 37], edge_to_edge_adj_matr=[19, 19]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 29], edge_index=[2, 15], edge_attr=[8, 15], y=[15], node_to_node_adj_matr=[29, 29], node_to_edge_adj_matr=[29, 15], edge_to_node_adj_matr=[15, 29], edge_to_edge_adj_matr=[15, 15]),
#  Data(x=[6, 23], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[23, 23], node_to_edge_adj_matr=[23, 12], edge_to_node_adj_matr=[12, 23], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 21], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[21, 21], node_to_edge_adj_matr=[21, 11], edge_to_node_adj_matr=[11, 21], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 25], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[25, 25], node_to_edge_adj_matr=[25, 13], edge_to_node_adj_matr=[13, 25], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 24], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 13], edge_to_node_adj_matr=[13, 24], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 21], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[21, 21], node_to_edge_adj_matr=[21, 11], edge_to_node_adj_matr=[11, 21], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 40], edge_index=[2, 21], edge_attr=[8, 21], y=[21], node_to_node_adj_matr=[40, 40], node_to_edge_adj_matr=[40, 21], edge_to_node_adj_matr=[21, 40], edge_to_edge_adj_matr=[21, 21]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 37], edge_index=[2, 20], edge_attr=[8, 20], y=[20], node_to_node_adj_matr=[37, 37], node_to_edge_adj_matr=[37, 20], edge_to_node_adj_matr=[20, 37], edge_to_edge_adj_matr=[20, 20]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 35], edge_index=[2, 18], edge_attr=[8, 18], y=[18], node_to_node_adj_matr=[35, 35], node_to_edge_adj_matr=[35, 18], edge_to_node_adj_matr=[18, 35], edge_to_edge_adj_matr=[18, 18]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 25], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[25, 25], node_to_edge_adj_matr=[25, 13], edge_to_node_adj_matr=[13, 25], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 25], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[25, 25], node_to_edge_adj_matr=[25, 13], edge_to_node_adj_matr=[13, 25], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 31], edge_index=[2, 16], edge_attr=[8, 16], y=[16], node_to_node_adj_matr=[31, 31], node_to_edge_adj_matr=[31, 16], edge_to_node_adj_matr=[16, 31], edge_to_edge_adj_matr=[16, 16]),
#  Data(x=[6, 15], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[15, 15], node_to_edge_adj_matr=[15, 8], edge_to_node_adj_matr=[8, 15], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 4], edge_index=[2, 2], edge_attr=[8, 2], y=[2], node_to_node_adj_matr=[4, 4], node_to_edge_adj_matr=[4, 2], edge_to_node_adj_matr=[2, 4], edge_to_edge_adj_matr=[2, 2]),
#  Data(x=[6, 7], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[7, 7], node_to_edge_adj_matr=[7, 4], edge_to_node_adj_matr=[4, 7], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 23], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[23, 23], node_to_edge_adj_matr=[23, 12], edge_to_node_adj_matr=[12, 23], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 6], edge_index=[2, 3], edge_attr=[8, 3], y=[3], node_to_node_adj_matr=[6, 6], node_to_edge_adj_matr=[6, 3], edge_to_node_adj_matr=[3, 6], edge_to_edge_adj_matr=[3, 3]),
#  Data(x=[6, 31], edge_index=[2, 16], edge_attr=[8, 16], y=[16], node_to_node_adj_matr=[31, 31], node_to_edge_adj_matr=[31, 16], edge_to_node_adj_matr=[16, 31], edge_to_edge_adj_matr=[16, 16]),
#  Data(x=[6, 21], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[21, 21], node_to_edge_adj_matr=[21, 11], edge_to_node_adj_matr=[11, 21], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 4], edge_index=[2, 2], edge_attr=[8, 2], y=[2], node_to_node_adj_matr=[4, 4], node_to_edge_adj_matr=[4, 2], edge_to_node_adj_matr=[2, 4], edge_to_edge_adj_matr=[2, 2]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 13], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[13, 13], node_to_edge_adj_matr=[13, 7], edge_to_node_adj_matr=[7, 13], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 19], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[19, 19], node_to_edge_adj_matr=[19, 10], edge_to_node_adj_matr=[10, 19], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 23], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[23, 23], node_to_edge_adj_matr=[23, 12], edge_to_node_adj_matr=[12, 23], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 15], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[15, 15], node_to_edge_adj_matr=[15, 8], edge_to_node_adj_matr=[8, 15], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 4], edge_index=[2, 2], edge_attr=[8, 2], y=[2], node_to_node_adj_matr=[4, 4], node_to_edge_adj_matr=[4, 2], edge_to_node_adj_matr=[2, 4], edge_to_edge_adj_matr=[2, 2]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
# ...
#  Data(x=[6, 17], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[17, 17], node_to_edge_adj_matr=[17, 9], edge_to_node_adj_matr=[9, 17], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 28], edge_index=[2, 14], edge_attr=[8, 14], y=[14], node_to_node_adj_matr=[28, 28], node_to_edge_adj_matr=[28, 14], edge_to_node_adj_matr=[14, 28], edge_to_edge_adj_matr=[14, 14]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 2], edge_index=[2, 1], edge_attr=[8, 1], y=[1], node_to_node_adj_matr=[2, 2], node_to_edge_adj_matr=[2, 1], edge_to_node_adj_matr=[1, 2], edge_to_edge_adj_matr=[1, 1]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 30], edge_index=[2, 15], edge_attr=[8, 15], y=[15], node_to_node_adj_matr=[30, 30], node_to_edge_adj_matr=[30, 15], edge_to_node_adj_matr=[15, 30], edge_to_edge_adj_matr=[15, 15]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 15], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[15, 15], node_to_edge_adj_matr=[15, 8], edge_to_node_adj_matr=[8, 15], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 6], edge_index=[2, 3], edge_attr=[8, 3], y=[3], node_to_node_adj_matr=[6, 6], node_to_edge_adj_matr=[6, 3], edge_to_node_adj_matr=[3, 6], edge_to_edge_adj_matr=[3, 3]),
#  Data(x=[6, 22], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 12], edge_to_node_adj_matr=[12, 22], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 4], edge_index=[2, 2], edge_attr=[8, 2], y=[2], node_to_node_adj_matr=[4, 4], node_to_edge_adj_matr=[4, 2], edge_to_node_adj_matr=[2, 4], edge_to_edge_adj_matr=[2, 2]),
#  Data(x=[6, 32], edge_index=[2, 16], edge_attr=[8, 16], y=[16], node_to_node_adj_matr=[32, 32], node_to_edge_adj_matr=[32, 16], edge_to_node_adj_matr=[16, 32], edge_to_edge_adj_matr=[16, 16]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 14], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[14, 14], node_to_edge_adj_matr=[14, 7], edge_to_node_adj_matr=[7, 14], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 13], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[13, 13], node_to_edge_adj_matr=[13, 7], edge_to_node_adj_matr=[7, 13], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 6], edge_index=[2, 3], edge_attr=[8, 3], y=[3], node_to_node_adj_matr=[6, 6], node_to_edge_adj_matr=[6, 3], edge_to_node_adj_matr=[3, 6], edge_to_edge_adj_matr=[3, 3]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 23], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[23, 23], node_to_edge_adj_matr=[23, 12], edge_to_node_adj_matr=[12, 23], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 15], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[15, 15], node_to_edge_adj_matr=[15, 8], edge_to_node_adj_matr=[8, 15], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 38], edge_index=[2, 19], edge_attr=[8, 19], y=[19], node_to_node_adj_matr=[38, 38], node_to_edge_adj_matr=[38, 19], edge_to_node_adj_matr=[19, 38], edge_to_edge_adj_matr=[19, 19]),
#  Data(x=[6, 24], edge_index=[2, 12], edge_attr=[8, 12], y=[12], node_to_node_adj_matr=[24, 24], node_to_edge_adj_matr=[24, 12], edge_to_node_adj_matr=[12, 24], edge_to_edge_adj_matr=[12, 12]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 31], edge_index=[2, 16], edge_attr=[8, 16], y=[16], node_to_node_adj_matr=[31, 31], node_to_edge_adj_matr=[31, 16], edge_to_node_adj_matr=[16, 31], edge_to_edge_adj_matr=[16, 16]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 26], edge_index=[2, 13], edge_attr=[8, 13], y=[13], node_to_node_adj_matr=[26, 26], node_to_edge_adj_matr=[26, 13], edge_to_node_adj_matr=[13, 26], edge_to_edge_adj_matr=[13, 13]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 20], edge_index=[2, 10], edge_attr=[8, 10], y=[10], node_to_node_adj_matr=[20, 20], node_to_edge_adj_matr=[20, 10], edge_to_node_adj_matr=[10, 20], edge_to_edge_adj_matr=[10, 10]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 15], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[15, 15], node_to_edge_adj_matr=[15, 8], edge_to_node_adj_matr=[8, 15], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 13], edge_index=[2, 7], edge_attr=[8, 7], y=[7], node_to_node_adj_matr=[13, 13], node_to_edge_adj_matr=[13, 7], edge_to_node_adj_matr=[7, 13], edge_to_edge_adj_matr=[7, 7]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6]),
#  Data(x=[6, 8], edge_index=[2, 4], edge_attr=[8, 4], y=[4], node_to_node_adj_matr=[8, 8], node_to_edge_adj_matr=[8, 4], edge_to_node_adj_matr=[4, 8], edge_to_edge_adj_matr=[4, 4]),
#  Data(x=[6, 10], edge_index=[2, 5], edge_attr=[8, 5], y=[5], node_to_node_adj_matr=[10, 10], node_to_edge_adj_matr=[10, 5], edge_to_node_adj_matr=[5, 10], edge_to_edge_adj_matr=[5, 5]),
#  Data(x=[6, 4], edge_index=[2, 2], edge_attr=[8, 2], y=[2], node_to_node_adj_matr=[4, 4], node_to_edge_adj_matr=[4, 2], edge_to_node_adj_matr=[2, 4], edge_to_edge_adj_matr=[2, 2]),
#  Data(x=[6, 6], edge_index=[2, 3], edge_attr=[8, 3], y=[3], node_to_node_adj_matr=[6, 6], node_to_edge_adj_matr=[6, 3], edge_to_node_adj_matr=[3, 6], edge_to_edge_adj_matr=[3, 3]),
#  Data(x=[6, 18], edge_index=[2, 9], edge_attr=[8, 9], y=[9], node_to_node_adj_matr=[18, 18], node_to_edge_adj_matr=[18, 9], edge_to_node_adj_matr=[9, 18], edge_to_edge_adj_matr=[9, 9]),
#  Data(x=[6, 16], edge_index=[2, 8], edge_attr=[8, 8], y=[8], node_to_node_adj_matr=[16, 16], node_to_edge_adj_matr=[16, 8], edge_to_node_adj_matr=[8, 16], edge_to_edge_adj_matr=[8, 8]),
#  Data(x=[6, 22], edge_index=[2, 11], edge_attr=[8, 11], y=[11], node_to_node_adj_matr=[22, 22], node_to_edge_adj_matr=[22, 11], edge_to_node_adj_matr=[11, 22], edge_to_edge_adj_matr=[11, 11]),
#  Data(x=[6, 12], edge_index=[2, 6], edge_attr=[8, 6], y=[6], node_to_node_adj_matr=[12, 12], node_to_edge_adj_matr=[12, 6], edge_to_node_adj_matr=[6, 12], edge_to_edge_adj_matr=[6, 6])]

# %%
dataset[0]
# Out:
# Data(x=[6, 37], edge_index=[2, 19], edge_attr=[8, 19], y=[19], node_to_node_adj_matr=[37, 37], node_to_edge_adj_matr=[37, 19], edge_to_node_adj_matr=[19, 37], edge_to_edge_adj_matr=[19, 19])

# %%
edge_index = dataset[0].edge_to_edge_adj_matr - torch.eye(dataset[0].edge_to_edge_adj_matr.shape[0])

# %%
edge_index = edge_index + edge_index.T

# %%
edge_index = edge_index.nonzero()

# %%
edge_index
# Out:
# tensor([], size=(0, 2), dtype=torch.int64)

# %%
dataset[0].edge_attr
# Out:
# tensor([[0.0170, 0.0065, 0.0145, 0.0145, 0.0055, 0.0806, 0.0096, 0.0063, 0.0128,
#          0.0108, 0.0142, 0.0099, 0.0064, 0.0072, 0.0557, 0.0122, 0.0077, 0.0058,
#          0.0086],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 1.0000, 1.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000,
#          0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 1.0000, 1.0000, 0.0000, 1.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#          1.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000,
#          0.0000, 0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#          1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], dtype=torch.float64)

# %%
from torch_geometric.data import Data

new_dataset = []

for data in dataset:
    edge_index = data.edge_to_edge_adj_matr - torch.eye(data.edge_to_edge_adj_matr.shape[0])
    edge_index = edge_index + edge_index.T
    edge_index = edge_index.nonzero()
    x = data.edge_attr
    y = data.y
    new_data = Data(
        x = x,
        y = y,
        edge_index = edge_index
    )
    new_dataset.append(new_data)

# %%
new_dataset
# Out:
# [Data(x=[8, 19], edge_index=[0, 2], y=[19]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 19], edge_index=[0, 2], y=[19]),
#  Data(x=[8, 8], edge_index=[2, 2], y=[8]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 6], edge_index=[2, 2], y=[6]),
#  Data(x=[8, 16], edge_index=[2, 2], y=[16]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 13], edge_index=[2, 2], y=[13]),
#  Data(x=[8, 12], edge_index=[2, 2], y=[12]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 2], edge_index=[0, 2], y=[2]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 12], edge_index=[4, 2], y=[12]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 8], edge_index=[2, 2], y=[8]),
#  Data(x=[8, 16], edge_index=[0, 2], y=[16]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 10], edge_index=[2, 2], y=[10]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 17], edge_index=[0, 2], y=[17]),
#  Data(x=[8, 14], edge_index=[0, 2], y=[14]),
#  Data(x=[8, 15], edge_index=[2, 2], y=[15]),
#  Data(x=[8, 9], edge_index=[2, 2], y=[9]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 10], edge_index=[2, 2], y=[10]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 18], edge_index=[2, 2], y=[18]),
#  Data(x=[8, 19], edge_index=[2, 2], y=[19]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 16], edge_index=[2, 2], y=[16]),
#  Data(x=[8, 14], edge_index=[0, 2], y=[14]),
#  Data(x=[8, 15], edge_index=[0, 2], y=[15]),
#  Data(x=[8, 19], edge_index=[2, 2], y=[19]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 13], edge_index=[2, 2], y=[13]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 14], edge_index=[0, 2], y=[14]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 15], edge_index=[2, 2], y=[15]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 2], edge_index=[0, 2], y=[2]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 17], edge_index=[2, 2], y=[17]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 9], edge_index=[2, 2], y=[9]),
#  Data(x=[8, 15], edge_index=[0, 2], y=[15]),
#  Data(x=[8, 14], edge_index=[0, 2], y=[14]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 2], edge_index=[0, 2], y=[2]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 14], edge_index=[4, 2], y=[14]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 11], edge_index=[2, 2], y=[11]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 15], edge_index=[0, 2], y=[15]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 8], edge_index=[2, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 9], edge_index=[2, 2], y=[9]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 16], edge_index=[2, 2], y=[16]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 10], edge_index=[2, 2], y=[10]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 10], edge_index=[4, 2], y=[10]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 10], edge_index=[4, 2], y=[10]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 7], edge_index=[2, 2], y=[7]),
#  Data(x=[8, 26], edge_index=[0, 2], y=[26]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 14], edge_index=[0, 2], y=[14]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 19], edge_index=[0, 2], y=[19]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 15], edge_index=[2, 2], y=[15]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 13], edge_index=[2, 2], y=[13]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 13], edge_index=[2, 2], y=[13]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 21], edge_index=[4, 2], y=[21]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 20], edge_index=[6, 2], y=[20]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 18], edge_index=[2, 2], y=[18]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 13], edge_index=[2, 2], y=[13]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 13], edge_index=[2, 2], y=[13]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 16], edge_index=[2, 2], y=[16]),
#  Data(x=[8, 8], edge_index=[2, 2], y=[8]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 2], edge_index=[0, 2], y=[2]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 16], edge_index=[2, 2], y=[16]),
#  Data(x=[8, 11], edge_index=[2, 2], y=[11]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 2], edge_index=[0, 2], y=[2]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 7], edge_index=[2, 2], y=[7]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 10], edge_index=[2, 2], y=[10]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 12], edge_index=[2, 2], y=[12]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 8], edge_index=[2, 2], y=[8]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 2], edge_index=[0, 2], y=[2]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 1], edge_index=[0, 2], y=[1]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 17], edge_index=[2, 2], y=[17]),
#  Data(x=[8, 9], edge_index=[4, 2], y=[9]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 8], edge_index=[2, 2], y=[8]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 16], edge_index=[0, 2], y=[16]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 9], edge_index=[2, 2], y=[9]),
#  Data(x=[8, 14], edge_index=[0, 2], y=[14]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 1], edge_index=[0, 2], y=[1]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 15], edge_index=[0, 2], y=[15]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 8], edge_index=[2, 2], y=[8]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 12], edge_index=[4, 2], y=[12]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 2], edge_index=[0, 2], y=[2]),
#  Data(x=[8, 16], edge_index=[0, 2], y=[16]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 7], edge_index=[0, 2], y=[7]),
#  Data(x=[8, 7], edge_index=[2, 2], y=[7]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 19], edge_index=[0, 2], y=[19]),
#  Data(x=[8, 12], edge_index=[0, 2], y=[12]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 16], edge_index=[2, 2], y=[16]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 13], edge_index=[0, 2], y=[13]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 10], edge_index=[0, 2], y=[10]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 8], edge_index=[2, 2], y=[8]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 7], edge_index=[2, 2], y=[7]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6]),
#  Data(x=[8, 4], edge_index=[0, 2], y=[4]),
#  Data(x=[8, 5], edge_index=[0, 2], y=[5]),
#  Data(x=[8, 2], edge_index=[0, 2], y=[2]),
#  Data(x=[8, 3], edge_index=[0, 2], y=[3]),
#  Data(x=[8, 9], edge_index=[0, 2], y=[9]),
#  Data(x=[8, 8], edge_index=[0, 2], y=[8]),
#  Data(x=[8, 11], edge_index=[0, 2], y=[11]),
#  Data(x=[8, 6], edge_index=[0, 2], y=[6])]

# %%
import torch
import torch.nn.functional as F
import torch_geometric.nn as nn
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# %%
hidden_size = 100
n_classes = 2


class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        self.conv1 = nn.GCNConv(8,16, bias=False)
        self.act1 = torch.nn.ReLU()
        self.conv2 = nn.GCNConv(16,2, bias=False)
        self.act2 = torch.nn.Softmax(dim=1)
    
    def forward(self, x, edge_index, batch_index):
        hidden1 = self.conv1(x, edge_index)
        hidden2 = self.act1(hidden1)
        hidden3 = self.conv2(hidden2, edge_index)
        output = self.act2(hidden3)
        
        return hidden3, output

# %%
model = GCN()

# %%
## Use a GPU para treinar
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
loss = torch.nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
train_data = new_dataset[0:int(0.8*366)]
test_data = new_dataset[int(0.8*366):]

# %%
train_data[0]
# Out:
# Data(x=[8, 19], edge_index=[0, 2], y=[19])

# %%
def train():
    model.train()
    # Enumerar sobre os dados.
    for epoch in range(100):
        for ts, data in enumerate(train_data):
            # Usar GPU
            data.to(device)
            # Resetar Gradientes
            optimizer.zero_grad()
            # Passando as informações do batch e de conexão dos grafos
            hidden, logits = model(data.x.T.float(), data.edge_index.T, None)
            #label_pred = pred.max(1)[1]
            # Calculando a perda e os gradientes.
            l = loss(logits, data.y.T)
            l.backward()
            # Atualizar usando os gradientes.
            optimizer.step()
        print('epoch =', epoch + 1, 'loss =', l.item())

# %%
train()
# Out:
# epoch = 1 loss = 0.36507198214530945
# epoch = 2 loss = 0.3522147834300995
# epoch = 3 loss = 0.3443557918071747
# epoch = 4 loss = 0.33724358677864075
# epoch = 5 loss = 0.3301285207271576
# epoch = 6 loss = 0.3245883882045746
# epoch = 7 loss = 0.3204250931739807
# epoch = 8 loss = 0.3170759975910187
# epoch = 9 loss = 0.3156054615974426
# epoch = 10 loss = 0.31463027000427246
# epoch = 11 loss = 0.31402865052223206
# epoch = 12 loss = 0.31368908286094666
# epoch = 13 loss = 0.31349870562553406
# epoch = 14 loss = 0.3133874535560608
# epoch = 15 loss = 0.31332510709762573
# epoch = 16 loss = 0.31329572200775146
# epoch = 17 loss = 0.3132798969745636
# epoch = 18 loss = 0.31327134370803833
# epoch = 19 loss = 0.3132668137550354
# epoch = 20 loss = 0.313264399766922
# epoch = 21 loss = 0.3132631182670593
# epoch = 22 loss = 0.3132624924182892
# epoch = 23 loss = 0.31326210498809814
# epoch = 24 loss = 0.3132619261741638
# epoch = 25 loss = 0.31326180696487427
# epoch = 26 loss = 0.3132617473602295
# epoch = 27 loss = 0.3132616877555847
# epoch = 28 loss = 0.3132616877555847
# epoch = 29 loss = 0.31326165795326233
# epoch = 30 loss = 0.31326165795326233
# epoch = 31 loss = 0.31326165795326233
# epoch = 32 loss = 0.31326165795326233
# epoch = 33 loss = 0.31326165795326233
# epoch = 34 loss = 0.31326165795326233
# epoch = 35 loss = 0.31326165795326233
# epoch = 36 loss = 0.31326165795326233
# epoch = 37 loss = 0.31326165795326233
# epoch = 38 loss = 0.31326165795326233
# epoch = 39 loss = 0.31326165795326233
# epoch = 40 loss = 0.31326165795326233
# epoch = 41 loss = 0.31326165795326233
# epoch = 42 loss = 0.31326165795326233
# epoch = 43 loss = 0.31326165795326233
# epoch = 44 loss = 0.31326165795326233
# epoch = 45 loss = 0.31326165795326233
# epoch = 46 loss = 0.31326165795326233
# epoch = 47 loss = 0.31326165795326233
# epoch = 48 loss = 0.31326165795326233
# epoch = 49 loss = 0.31326165795326233
# epoch = 50 loss = 0.31326165795326233
# epoch = 51 loss = 0.31326165795326233
# epoch = 52 loss = 0.31326165795326233
# epoch = 53 loss = 0.31326165795326233
# epoch = 54 loss = 0.31326165795326233
# epoch = 55 loss = 0.31326165795326233
# epoch = 56 loss = 0.31326165795326233
# epoch = 57 loss = 0.31326165795326233
# epoch = 58 loss = 0.31326165795326233
# epoch = 59 loss = 0.31326165795326233
# epoch = 60 loss = 0.31326165795326233
# epoch = 61 loss = 0.31326165795326233
# epoch = 62 loss = 0.31326165795326233
# epoch = 63 loss = 0.31326165795326233
# epoch = 64 loss = 0.31326165795326233
# epoch = 65 loss = 0.31326165795326233
# epoch = 66 loss = 0.31326165795326233
# epoch = 67 loss = 0.31326165795326233
# epoch = 68 loss = 0.31326165795326233
# epoch = 69 loss = 0.31326165795326233
# epoch = 70 loss = 0.31326165795326233
# epoch = 71 loss = 0.31326165795326233
# epoch = 72 loss = 0.31326165795326233
# epoch = 73 loss = 0.31326165795326233
# epoch = 74 loss = 0.31326165795326233
# epoch = 75 loss = 0.31326165795326233
# epoch = 76 loss = 0.31326165795326233
# epoch = 77 loss = 0.31326165795326233
# epoch = 78 loss = 0.31326165795326233
# epoch = 79 loss = 0.31326165795326233
# epoch = 80 loss = 0.31326165795326233
# epoch = 81 loss = 0.31326165795326233
# epoch = 82 loss = 0.31326165795326233
# epoch = 83 loss = 0.31326165795326233
# epoch = 84 loss = 0.31326165795326233
# epoch = 85 loss = 0.31326165795326233
# epoch = 86 loss = 0.31326165795326233
# epoch = 87 loss = 0.31326165795326233
# epoch = 88 loss = 0.31326165795326233
# epoch = 89 loss = 0.31326165795326233
# epoch = 90 loss = 0.31326165795326233
# epoch = 91 loss = 0.31326165795326233
# epoch = 92 loss = 0.31326165795326233
# epoch = 93 loss = 0.31326165795326233
# epoch = 94 loss = 0.31326165795326233
# epoch = 95 loss = 0.31326165795326233
# epoch = 96 loss = 0.31326165795326233
# epoch = 97 loss = 0.31326165795326233
# epoch = 98 loss = 0.31326165795326233
# epoch = 99 loss = 0.31326165795326233
# epoch = 100 loss = 0.31326165795326233

# %%
label_pred_list = []
y_true_list = []

def test():
    model.eval()
    with torch.no_grad():
        global label_pred_list
        global y_true_list
        for data in test_data:
            data.to(device)
            _, logits = model(data.x.T.float(), data.edge_index.T, None)
            label_pred = logits.max(1)[1].tolist()
            label_pred_list += label_pred
            y_true_list += data.y.tolist()
    model.train()

# %%
test()

# %%
mean_precision = []
mean_recall = []
mean_f1 = []

prec = precision_score(y_true_list, label_pred_list, average='binary', labels=[0])
rec = recall_score(y_true_list, label_pred_list, average='binary', labels=[0])
f1 = f1_score(y_true_list, label_pred_list, average='binary', labels=[0])

# %%
print(classification_report(y_true_list,label_pred_list))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93       418
#            1       0.75      0.99      0.85       165
#
#     accuracy                           0.90       583
#    macro avg       0.87      0.93      0.89       583
# weighted avg       0.93      0.90      0.91       583
