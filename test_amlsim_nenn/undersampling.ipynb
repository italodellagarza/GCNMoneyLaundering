# %% [markdown]
# # Realizando o Undersampling da Base de Dados

# %% [markdown]
# Fazendo um undersampling simples para equilibrar a presença de fraudes na base de dados em 50%.

# %%
import pandas as pd

# %%
transactions = pd.read_csv('new_1M/transactions.csv')

# %%
transactions
# Out:
#        step      type  amount  nameOrig  oldbalanceOrig  newbalanceOrig  \
# 0         0  TRANSFER  885.30       698        84687.88        83802.57
# 1         0  TRANSFER  546.86      2655        89391.40        88844.53
# 2         0  TRANSFER  400.97       145        86166.31        85765.33
# 3         0  TRANSFER  929.69       142        88100.68        87170.99
# 4         0  TRANSFER  310.25       444        86948.14        86637.89
# ...     ...       ...     ...       ...             ...             ...
# 68059   199  TRANSFER  274.76       490        43289.78        43015.01
# 68060   199  TRANSFER  133.94      2083        51125.03        50991.08
# 68061   199  TRANSFER  833.74      4704        69929.76        69096.02
# 68062   199  TRANSFER  826.36       289        58516.33        57689.96
# 68063   199  TRANSFER  910.06       737        47544.46        46634.39
#
#        nameDest  oldbalanceDest  newbalanceDest  isSAR  alertID
# 0            42        70573.82        71459.12      0       -1
# 1            18        62618.60        63165.46      0       -1
# 2            36        63348.53        63749.51      0       -1
# 3           177        81192.38        82122.07      0       -1
# 4            11        74170.67        74480.93      0       -1
# ...         ...             ...             ...    ...      ...
# 68059       148       123925.12       124199.89      0       -1
# 68060        13       715363.68       715497.68      0       -1
# 68061       112       102709.60       103543.35      0       -1
# 68062        42       351712.25       352538.62      0       -1
# 68063       118       106512.89       107422.96      0       -1
#
# [68064 rows x 11 columns]

# %%
len(transactions[transactions['isSAR'] == True])
# Out:
# 693

# %%
sample_falses = transactions[transactions['isSAR'] == False].sample(1039)

# %%
len(sample_falses.sort_values(by=['step']).step.unique())
# Out:
# 200

# %%
transactions[(transactions.index.isin(sample_falses.index))]
# Out:
#        step      type  amount  nameOrig  oldbalanceOrig  newbalanceOrig  \
# 56        0  TRANSFER  337.24       896        58916.75        58579.50
# 94        0  TRANSFER  326.32      4647        64657.26        64330.93
# 204       0  TRANSFER  611.53      2630        55895.03        55283.49
# 333       0  TRANSFER  574.51      4352        73515.89        72941.37
# 564       1  TRANSFER  423.24      2380        76306.39        75883.14
# ...     ...       ...     ...       ...             ...             ...
# 67574   198  TRANSFER  233.26      2661        23303.58        23070.32
# 67623   198  TRANSFER  463.41       566        39982.01        39518.60
# 67631   198  TRANSFER  869.75       546        45207.35        44337.59
# 67793   199  TRANSFER  428.89      4438        48460.05        48031.16
# 68034   199  TRANSFER  133.65      2497        14203.10        14069.45
#
#        nameDest  oldbalanceDest  newbalanceDest  isSAR  alertID
# 56           25        68471.10        68808.35      0       -1
# 94           53        81980.47        82306.80      0       -1
# 204          24        91577.35        92188.89      0       -1
# 333          45        91954.28        92528.79      0       -1
# 564          23        94553.89        94977.13      0       -1
# ...         ...             ...             ...    ...      ...
# 67574        15       423229.34       423462.62      0       -1
# 67623       116        99391.39        99854.80      0       -1
# 67631        24       610476.37       611346.12      0       -1
# 67793        14       658341.87       658770.75      0       -1
# 68034       327        84590.40        84724.05      0       -1
#
# [1039 rows x 11 columns]

# %%
sample_falses = sample_falses.reset_index()
transactions = transactions.reset_index()

# %%
balanced = transactions[(transactions['isSAR'] == True) | (transactions.index.isin(sample_falses.index))]

# %%
balanced
# Out:
#        step      type  amount  nameOrig  oldbalanceOrig  newbalanceOrig  \
# 16        0  TRANSFER  768.52      9128        63540.91        62772.38
# 24        0  TRANSFER  564.96      4650        63992.01        63427.05
# 43        0  TRANSFER  988.90      6492        59406.82        58417.92
# 56        0  TRANSFER  337.24       896        58916.75        58579.50
# 87        0  TRANSFER  132.40      3207        88289.99        88157.58
# ...     ...       ...     ...       ...             ...             ...
# 67623   198  TRANSFER  463.41       566        39982.01        39518.60
# 67631   198  TRANSFER  869.75       546        45207.35        44337.59
# 67793   199  TRANSFER  428.89      4438        48460.05        48031.16
# 67952   199  TRANSFER  424.41      2188        99740.56        99316.14
# 68034   199  TRANSFER  133.65      2497        14203.10        14069.45
#
#        nameDest  oldbalanceDest  newbalanceDest  isSAR  alertID
# 16           35        66900.31        67668.84      1       22
# 24          376        73429.79        73994.76      1        0
# 43          105        82521.53        83510.44      1        1
# 56           25        68471.10        68808.35      0       -1
# 87          531        95537.18        95669.59      1       13
# ...         ...             ...             ...    ...      ...
# 67623       116        99391.39        99854.80      0       -1
# 67631        24       610476.37       611346.12      0       -1
# 67793        14       658341.87       658770.75      0       -1
# 67952      4496        50701.06        51125.48      1       81
# 68034       327        84590.40        84724.05      0       -1
#
# [1732 rows x 11 columns]

# %%
balanced_account_set = set(balanced['nameOrig'].values.tolist() + balanced['nameDest'].values.tolist())

# %%
len(balanced_account_set)
# Out:
# 1654

# %%
accounts = pd.read_csv('new_1M/accounts.csv')

# %%
accounts
# Out:
#        acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 0            0      C_0    I         A              USD            False
# 1            1      C_1    I         A              USD             True
# 2            2      C_2    I         A              USD            False
# 3            3      C_3    I         A              USD            False
# 4            4      C_4    I         A              USD             True
# ...        ...      ...  ...       ...              ...              ...
# 12038    12038  C_12038    I         A              USD            False
# 12039    12039  C_12039    I         A              USD            False
# 12040    12040  C_12040    I         A              USD            False
# 12041    12041  C_12041    I         A              USD            False
# 12042    12042  C_12042    I         A              USD            False
#
#        branch_id  open_dt  close_dt  initial_deposit  ...  \
# 0              1        0   1000000         83514.28  ...
# 1              1        0   1000000         79773.83  ...
# 2              1        0   1000000         68338.65  ...
# 3              1        0   1000000         70199.02  ...
# 4              1        0   1000000         90042.39  ...
# ...          ...      ...       ...              ...  ...
# 12038          1        0   1000000         97535.02  ...
# 12039          1        0   1000000         54741.84  ...
# 12040          1        0   1000000         89682.42  ...
# 12041          1        0   1000000         54801.09  ...
# 12042          1        0   1000000         97179.11  ...
#
#                          street_addr             city state country    zip  \
# 0        48764 Howard Forge Apt. 421      Vanessaside    PA      US  19763
# 1          387 Grimes Green Apt. 801         Pagetown    NM      US  44165
# 2      15871 Arnold Squares Apt. 858      Port Carrie    LA      US  58826
# 3                    471 Erika Curve      North Megan    UT      US  71358
# 4          477 Miller Ridge Apt. 795       East Allen    DE      US  92950
# ...                              ...              ...   ...     ...    ...
# 12038              465 Jones Corners     Vasquezville    CT      US  64754
# 12039          461 Rodriguez Heights     Johnsonmouth    CO      US  61585
# 12040       542 Price Neck Suite 716  New Charlesfurt    MT      US  87030
# 12041                 233 Lisa Locks       Martinfort    KS      US  80840
# 12042            4969 Maldonado Wall  Port Philipfurt    PA      US  49385
#
#        gender  birth_date          ssn         lon        lat
# 0      Female  2021-12-27  701-43-7736  120.547683 -62.968225
# 1        Male  1914-10-23  196-73-3633  -51.894050 -51.749453
# 2        Male  1949-05-22  590-31-4757  -81.286230 -39.160654
# 3      Female  1977-08-19  283-67-3859  -64.464688  68.323549
# 4        Male  1951-07-01  437-08-1649 -101.424385 -31.273420
# ...       ...         ...          ...         ...        ...
# 12038  Female  1919-10-24  837-57-2223 -173.105523  -4.703172
# 12039  Female  2004-06-30  024-87-3981 -149.528693 -40.623546
# 12040    Male  1971-05-31  032-24-0745  103.724034 -82.369435
# 12041    Male  1910-02-05  440-56-4496 -110.818394 -40.116355
# 12042  Female  1954-02-12  196-01-7163   82.808151 -65.049218
#
# [12043 rows x 24 columns]

# %%
new_account_set = accounts[accounts['acct_id'].isin(balanced_account_set)]

# %%
new_account_set
# Out:
#        acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 0            0      C_0    I         A              USD            False
# 1            1      C_1    I         A              USD             True
# 2            2      C_2    I         A              USD            False
# 3            3      C_3    I         A              USD            False
# 4            4      C_4    I         A              USD             True
# ...        ...      ...  ...       ...              ...              ...
# 11991    11991  C_11991    I         A              USD             True
# 11994    11994  C_11994    I         A              USD             True
# 11998    11998  C_11998    I         A              USD             True
# 12007    12007  C_12007    I         A              USD             True
# 12008    12008  C_12008    I         A              USD             True
#
#        branch_id  open_dt  close_dt  initial_deposit  ...  \
# 0              1        0   1000000         83514.28  ...
# 1              1        0   1000000         79773.83  ...
# 2              1        0   1000000         68338.65  ...
# 3              1        0   1000000         70199.02  ...
# 4              1        0   1000000         90042.39  ...
# ...          ...      ...       ...              ...  ...
# 11991          1        0   1000000         69783.44  ...
# 11994          1        0   1000000         72809.19  ...
# 11998          1        0   1000000         60185.16  ...
# 12007          1        0   1000000         54769.21  ...
# 12008          1        0   1000000         89046.45  ...
#
#                          street_addr             city state country    zip  \
# 0        48764 Howard Forge Apt. 421      Vanessaside    PA      US  19763
# 1          387 Grimes Green Apt. 801         Pagetown    NM      US  44165
# 2      15871 Arnold Squares Apt. 858      Port Carrie    LA      US  58826
# 3                    471 Erika Curve      North Megan    UT      US  71358
# 4          477 Miller Ridge Apt. 795       East Allen    DE      US  92950
# ...                              ...              ...   ...     ...    ...
# 11991             9028 Wallace Shore     Bowenchester    KS      US  17475
# 11994             57803 Regina Forks  North Robinberg    LA      US   4144
# 11998      1890 Andrew Oval Apt. 023   Hernandezshire    NH      US  91061
# 12007         79846 Ramirez Overpass  Port Ellenburgh    SD      US  68087
# 12008      39792 Joshua Way Apt. 399         Hickston    IN      US  81478
#
#        gender  birth_date          ssn         lon        lat
# 0      Female  2021-12-27  701-43-7736  120.547683 -62.968225
# 1        Male  1914-10-23  196-73-3633  -51.894050 -51.749453
# 2        Male  1949-05-22  590-31-4757  -81.286230 -39.160654
# 3      Female  1977-08-19  283-67-3859  -64.464688  68.323549
# 4        Male  1951-07-01  437-08-1649 -101.424385 -31.273420
# ...       ...         ...          ...         ...        ...
# 11991  Female  1962-05-30  398-27-4668  -23.362833  86.110448
# 11994    Male  1981-09-08  395-87-6150 -175.556450 -35.996330
# 11998    Male  2012-07-10  728-94-7531 -100.856811 -36.180856
# 12007    Male  1949-06-12  452-01-9601 -101.595697  -7.761126
# 12008  Female  1927-01-13  451-84-8613 -116.069517 -67.468283
#
# [1654 rows x 24 columns]

# %%
new_account_set = new_account_set.reset_index(drop=True).reset_index()

# %%
new_account_set = new_account_set.rename(columns={'index': 'NEW_ACC_ID'})

# %%
new_account_set['NEW_CUSTOMER_ID'] = 'C_' + new_account_set['dsply_nm'].astype(str)

# %%
new_account_set
# Out:
#       NEW_ACC_ID  acct_id dsply_nm type acct_stat acct_rptng_crncy  \
# 0              0        0      C_0    I         A              USD
# 1              1        1      C_1    I         A              USD
# 2              2        2      C_2    I         A              USD
# 3              3        3      C_3    I         A              USD
# 4              4        4      C_4    I         A              USD
# ...          ...      ...      ...  ...       ...              ...
# 1649        1649    11991  C_11991    I         A              USD
# 1650        1650    11994  C_11994    I         A              USD
# 1651        1651    11998  C_11998    I         A              USD
# 1652        1652    12007  C_12007    I         A              USD
# 1653        1653    12008  C_12008    I         A              USD
#
#       prior_sar_count  branch_id  open_dt  close_dt  ...             city  \
# 0               False          1        0   1000000  ...      Vanessaside
# 1                True          1        0   1000000  ...         Pagetown
# 2               False          1        0   1000000  ...      Port Carrie
# 3               False          1        0   1000000  ...      North Megan
# 4                True          1        0   1000000  ...       East Allen
# ...               ...        ...      ...       ...  ...              ...
# 1649             True          1        0   1000000  ...     Bowenchester
# 1650             True          1        0   1000000  ...  North Robinberg
# 1651             True          1        0   1000000  ...   Hernandezshire
# 1652             True          1        0   1000000  ...  Port Ellenburgh
# 1653             True          1        0   1000000  ...         Hickston
#
#       state country    zip  gender  birth_date          ssn         lon  \
# 0        PA      US  19763  Female  2021-12-27  701-43-7736  120.547683
# 1        NM      US  44165    Male  1914-10-23  196-73-3633  -51.894050
# 2        LA      US  58826    Male  1949-05-22  590-31-4757  -81.286230
# 3        UT      US  71358  Female  1977-08-19  283-67-3859  -64.464688
# 4        DE      US  92950    Male  1951-07-01  437-08-1649 -101.424385
# ...     ...     ...    ...     ...         ...          ...         ...
# 1649     KS      US  17475  Female  1962-05-30  398-27-4668  -23.362833
# 1650     LA      US   4144    Male  1981-09-08  395-87-6150 -175.556450
# 1651     NH      US  91061    Male  2012-07-10  728-94-7531 -100.856811
# 1652     SD      US  68087    Male  1949-06-12  452-01-9601 -101.595697
# 1653     IN      US  81478  Female  1927-01-13  451-84-8613 -116.069517
#
#             lat  NEW_CUSTOMER_ID
# 0    -62.968225            C_C_0
# 1    -51.749453            C_C_1
# 2    -39.160654            C_C_2
# 3     68.323549            C_C_3
# 4    -31.273420            C_C_4
# ...         ...              ...
# 1649  86.110448        C_C_11991
# 1650 -35.996330        C_C_11994
# 1651 -36.180856        C_C_11998
# 1652  -7.761126        C_C_12007
# 1653 -67.468283        C_C_12008
#
# [1654 rows x 26 columns]

# %%
keys = new_account_set.acct_id.values
values = new_account_set.NEW_ACC_ID.values

parse_keys = {}

for k, v in zip(keys, values):
    parse_keys[k] = v

# %%
def convert_to_new(line):
    line['nameOrig'] = parse_keys[line['nameOrig']]
    line['nameDest'] = parse_keys[line['nameDest']]
    return line

# %%
balanced = balanced.apply(convert_to_new, axis=1)

# %%
balanced
# Out:
#        step      type  amount  nameOrig  oldbalanceOrig  newbalanceOrig  \
# 16        0  TRANSFER  768.52      1491        63540.91        62772.38
# 24        0  TRANSFER  564.96      1164        63992.01        63427.05
# 43        0  TRANSFER  988.90      1330        59406.82        58417.92
# 56        0  TRANSFER  337.24       541        58916.75        58579.50
# 87        0  TRANSFER  132.40       994        88289.99        88157.58
# ...     ...       ...     ...       ...             ...             ...
# 67623   198  TRANSFER  463.41       404        39982.01        39518.60
# 67631   198  TRANSFER  869.75       394        45207.35        44337.59
# 67793   199  TRANSFER  428.89      1146        48460.05        48031.16
# 67952   199  TRANSFER  424.41       677        99740.56        99316.14
# 68034   199  TRANSFER  133.65       742        14203.10        14069.45
#
#        nameDest  oldbalanceDest  newbalanceDest  isSAR  alertID
# 16           35        66900.31        67668.84      1       22
# 24          283        73429.79        73994.76      1        0
# 43           99        82521.53        83510.44      1        1
# 56           25        68471.10        68808.35      0       -1
# 87          381        95537.18        95669.59      1       13
# ...         ...             ...             ...    ...      ...
# 67623       110        99391.39        99854.80      0       -1
# 67631        24       610476.37       611346.12      0       -1
# 67793        14       658341.87       658770.75      0       -1
# 67952      1153        50701.06        51125.48      1       81
# 68034       254        84590.40        84724.05      0       -1
#
# [1732 rows x 11 columns]

# %%
new_account_set.acct_id = new_account_set.NEW_ACC_ID
new_account_set.dsply_nm = new_account_set.NEW_CUSTOMER_ID

# %%
new_account_set = new_account_set.drop(['NEW_ACC_ID', 'NEW_CUSTOMER_ID'],axis=1)

# %%
new_account_set.to_csv('new_1M/accounts_undersampling.csv')
balanced.to_csv('new_1M/transactions_undersampling.csv')
